# %% [markdown]
# <a href="https://colab.research.google.com/github/Onamihoang/NLP-BERT/blob/master/Test_Fit_with_Albert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/Onamihoang/fitbert.git
# Out:
# Cloning into 'fitbert'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 401 (delta 92), reused 101 (delta 46), pack-reused 233
# Receiving objects: 100% (401/401), 383.70 KiB | 522.00 KiB/s, done.
# Resolving deltas: 100% (213/213), done.

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 645kB 8.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 46.1MB/s
# ...
#      |████████████████████████████████| 3.8MB 48.2MB/s
# ...
#      |████████████████████████████████| 890kB 38.1MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=3c62ef3cd3544efe463f7d045cfff2f44ca689955322cf4dd13573bceb2954f0
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
cd fitbert
# Out:
# /content/fitbert

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 51kB 7.4MB/s
# ...
#      |████████████████████████████████| 61kB 9.6MB/s
# ...
#   Created wheel for dill: filename=dill-0.2.5-cp36-none-any.whl size=52421 sha256=47bca1b7ae0424d74a4a206e2a7c8f801756c4460244e538441dd508033a04a6
#   Stored in directory: /root/.cache/pip/wheels/d0/f9/bb/01e2c9bc71ab75df06848f7eb23aa58b0e24713332aee81aa2
# Successfully built dill
# ERROR: multiprocess 0.70.9 has requirement dill>=0.3.1, but you'll have dill 0.2.5 which is incompatible.
# ...
#   Found existing installation: dill 0.3.1.1
#     Uninstalling dill-0.3.1.1:
#       Successfully uninstalled dill-0.3.1.1
# ...

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating fitbert.egg-info
# writing fitbert.egg-info/PKG-INFO
# writing dependency_links to fitbert.egg-info/dependency_links.txt
# writing requirements to fitbert.egg-info/requires.txt
# writing top-level names to fitbert.egg-info/top_level.txt
# writing manifest file 'fitbert.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'fitbert.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/fitbert
# copying fitbert/__init__.py -> build/lib/fitbert
# copying fitbert/version.py -> build/lib/fitbert
# copying fitbert/utils.py -> build/lib/fitbert
# copying fitbert/delemmatize.py -> build/lib/fitbert
# copying fitbert/tests.py -> build/lib/fitbert
# copying fitbert/fitb.py -> build/lib/fitbert
# creating build/lib/fitbert/data
# ...

# %%
from fitbert import FitBert

fb = FitBert()
# Out:
# using model: bert-large-uncased
# device: cuda
# ...

# %%
masked_string = "Why Bert, you're looking ***mask*** today!"
options = ['buff', 'handsome', 'strong']

ranked_options = fb.rank(masked_string, options=options)
print(ranked_options[0])
# Out:
# handsome

# %%
import re
ques , ans = '',''
opt = []
arr = []
dung, sai, tong = 0,0,0
import json
with open('/content/data.json', 'r') as f:
    data = json.load(f)
    for (k, row) in data.items():
        ques = data[k]['question']
        arr.append(data[k]['1'])
        arr.append(data[k]['2'])
        arr.append(data[k]['3'])
        arr.append(data[k]['4'])
        ans = data[k]['anwser']
        if re.search('___',ques):
            ques = re.sub('___','***mask***', ques)
            ranked_options = fb.rank(ques, options=arr)
            tong +=1
            #print(tong)
            if ranked_options[0] == ans:
                dung +=1
            else:
                sai+=1
                print(ques)
                print(arr,ans, ranked_options[0])
            arr = []
            ques, ans = '',''
        else:
            print(' Cau hoi bi bi loi')
print(dung)
print(sai)
# Out:
# Our apartment building's occupancy increased ***mask*** the efforts of our knowledgeable and friendly rental agent, Ms. Gova.
# ['despite', 'due to', 'provided that', 'because'] due to despite
# Rosalind Media Ltd. came up with the idea to hire artists to create ***mask*** artworks for the purpose of marketing.
# ['originator', 'original', 'originally', 'originality'] original originality
# For defective merchandise, we will gladly ***mask*** the product or give you a full refund.
# ['replace', 'cause', 'interfere', 'return'] replace return
# Open Society Institute has ***mask*** offered to sponsor a number of participants from developing countries for attendance at the OA Workshop.
# ['enormously', 'financially', 'exceptionally', 'generously'] generously financially
# All the employees at SEI Corporation are invited to the meeting ***mask*** the new internal communications system that the company is about to bring in.
# ['at', 'with', 'on', 'over'] on with
# ...
